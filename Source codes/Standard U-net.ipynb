# %%
#Construction of Standard Unet

# %%
#import libraries for model development
from keras import models, layers
from keras import backend as K

# %%
#Definition of convolution block

def conv_block(inputs, filter_size, size, dropout, batch_norm=True):

    conv = layers.Conv2D(size, (filter_size, filter_size), padding='same')(inputs)

    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)

    conv = layers.Activation('relu')(conv)

    if dropout > 0:
        conv = layers.Dropout(dropout)(conv)

    return conv

# %%
#Definition of Unet architecture

def Unet(input_shape, NUM_CLASSES, dropout_rate, batch_norm):

    # network structure
    FILTER_NUM = 32 # number of filters for the first layer
    FILTER_SIZE = 3 # size of the convolutional filter
    UP_SAMP_SIZE = 2 # size of upsampling filters

    inputs = layers.Input(input_shape)

    # Downsampling layers

    # DownRes 1, convolution + pooling
    conv_1 = conv_block(inputs, FILTER_SIZE, 1*FILTER_NUM, dropout_rate, batch_norm)
    pool_1 = layers.MaxPooling2D(pool_size=(2,2))(conv_1)

    # DownRes 2, convolution + pooling
    conv_2 = conv_block(pool_1, FILTER_SIZE, 2*FILTER_NUM, dropout_rate, batch_norm)
    pool_2 = layers.MaxPooling2D(pool_size=(2,2))(conv_2)

    # DownRes 3, convolution + pooling
    conv_3 = conv_block(pool_2, FILTER_SIZE, 4*FILTER_NUM, dropout_rate, batch_norm)
    pool_3 = layers.MaxPooling2D(pool_size=(2,2))(conv_3)

    # DownRes 4
    conv_4 = conv_block(pool_3, FILTER_SIZE, 8*FILTER_NUM, dropout_rate, batch_norm)
    pool_4 = layers.MaxPooling2D(pool_size=(2,2))(conv_4)

    # DownRes 5, convolution only
    conv_5 = conv_block(pool_4, FILTER_SIZE, 16*FILTER_NUM, dropout_rate, batch_norm)


    # UpRes 1, upsampling  + concatenate
    up_1 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(conv_5)
    up_1 = layers.concatenate([up_1, conv_4], axis=3)
    up_conv_1 = conv_block(up_1, FILTER_SIZE, 8*FILTER_NUM, dropout_rate, batch_norm)
   
    # UpRes 2, upsampling  + concatenate
    up_2 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_1)
    up_2 = layers.concatenate([up_2, conv_3], axis=3)
    up_conv_2 = conv_block(up_2, FILTER_SIZE, 4*FILTER_NUM, dropout_rate, batch_norm)
    
    # UpRes 3, upsampling  + concatenate
    up_3 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_2)
    up_3 = layers.concatenate([up_3, conv_2], axis=3)
    up_conv_3 = conv_block(up_3, FILTER_SIZE, 2*FILTER_NUM, dropout_rate, batch_norm)

    # UpRes 4, upsampling  + concatenate
    up_4 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_3)
    up_4 = layers.concatenate([up_4, conv_1], axis=3)
    up_conv_4 = conv_block(up_4, FILTER_SIZE, 1*FILTER_NUM, dropout_rate, batch_norm)

    # 1*1 convolutional layers
    conv_final = layers.Conv2D(NUM_CLASSES, kernel_size=(1,1))(up_conv_4)
    conv_final = layers.BatchNormalization(axis=3)(conv_final)
    conv_final = layers.Activation('softmax')(conv_final)  #Change to softmax for multichannel

    # Model 
    model = models.Model(inputs, conv_final, name="Unet")

    print(model.summary())

    return model

# %%
#Size of images and input shape

SIZE_X = 256 
SIZE_Y = 512
input_shape = (SIZE_X,SIZE_Y,1)

#Number of classes for segmentation
n_classes=5

# %%
#create the AM_SegNet model

model = Unet(input_shape, NUM_CLASSES=5, dropout_rate=0.0, batch_norm=True)
# Out:
# Model: "Unet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 256, 512, 1  0           []
#                                 )]
#
#  conv2d_10 (Conv2D)             (None, 256, 512, 32  320         ['input_2[0][0]']
#                                 )
#
#  batch_normalization_10 (BatchN  (None, 256, 512, 32  128        ['conv2d_10[0][0]']
#  ormalization)                  )
#
#  activation_10 (Activation)     (None, 256, 512, 32  0           ['batch_normalization_10[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 128, 256, 32  0          ['activation_10[0][0]']
#                                 )
#
#  conv2d_11 (Conv2D)             (None, 128, 256, 64  18496       ['max_pooling2d_4[0][0]']
#                                 )
#
#  batch_normalization_11 (BatchN  (None, 128, 256, 64  256        ['conv2d_11[0][0]']
#  ormalization)                  )
#
#  activation_11 (Activation)     (None, 128, 256, 64  0           ['batch_normalization_11[0][0]']
#                                 )
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 64, 128, 64)  0          ['activation_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 64, 128, 128  73856       ['max_pooling2d_5[0][0]']
#                                 )
#
#  batch_normalization_12 (BatchN  (None, 64, 128, 128  512        ['conv2d_12[0][0]']
#  ormalization)                  )
#
#  activation_12 (Activation)     (None, 64, 128, 128  0           ['batch_normalization_12[0][0]']
#                                 )
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 32, 64, 128)  0          ['activation_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 64, 256)  295168      ['max_pooling2d_6[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 32, 64, 256)  1024       ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 32, 64, 256)  0           ['batch_normalization_13[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 16, 32, 256)  0          ['activation_13[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 16, 32, 512)  1180160     ['max_pooling2d_7[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 16, 32, 512)  2048       ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 16, 32, 512)  0           ['batch_normalization_14[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (None, 32, 64, 512)  0          ['activation_14[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 32, 64, 768)  0           ['up_sampling2d_4[0][0]',
#                                                                   'activation_13[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 32, 64, 256)  1769728     ['concatenate_4[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 32, 64, 256)  1024       ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 32, 64, 256)  0           ['batch_normalization_15[0][0]']
#
#  up_sampling2d_5 (UpSampling2D)  (None, 64, 128, 256  0          ['activation_15[0][0]']
#                                 )
#
#  concatenate_5 (Concatenate)    (None, 64, 128, 384  0           ['up_sampling2d_5[0][0]',
#                                 )                                 'activation_12[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 64, 128, 128  442496      ['concatenate_5[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 64, 128, 128  512        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  activation_16 (Activation)     (None, 64, 128, 128  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  up_sampling2d_6 (UpSampling2D)  (None, 128, 256, 12  0          ['activation_16[0][0]']
#                                 8)
#
#  concatenate_6 (Concatenate)    (None, 128, 256, 19  0           ['up_sampling2d_6[0][0]',
#                                 2)                                'activation_11[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 128, 256, 64  110656      ['concatenate_6[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 128, 256, 64  256        ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  activation_17 (Activation)     (None, 128, 256, 64  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  up_sampling2d_7 (UpSampling2D)  (None, 256, 512, 64  0          ['activation_17[0][0]']
#                                 )
#
#  concatenate_7 (Concatenate)    (None, 256, 512, 96  0           ['up_sampling2d_7[0][0]',
#                                 )                                 'activation_10[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 256, 512, 32  27680       ['concatenate_7[0][0]']
#                                 )
#
#  batch_normalization_18 (BatchN  (None, 256, 512, 32  128        ['conv2d_18[0][0]']
#  ormalization)                  )
#
#  activation_18 (Activation)     (None, 256, 512, 32  0           ['batch_normalization_18[0][0]']
#                                 )
#
#  conv2d_19 (Conv2D)             (None, 256, 512, 5)  165         ['activation_18[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 256, 512, 5)  20         ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 256, 512, 5)  0           ['batch_normalization_19[0][0]']
#
# ==================================================================================================
# Total params: 3,924,633
# Trainable params: 3,921,679
# Non-trainable params: 2,954
# __________________________________________________________________________________________________
# None
